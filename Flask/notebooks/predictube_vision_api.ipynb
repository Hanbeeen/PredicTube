# %%
import os

# JSON 키 파일의 경로를 환경 변수로 설정
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./keys/august-bond-397606-9fed2249633b.json"

# %%
import csv
from google.cloud import vision
from google.api_core.exceptions import ResourceExhausted

def process_image(client, image_url):
    """
    Google Cloud Vision API를 사용하여 이미지를 처리하고 관련 정보를 추출합니다.

    Args:
    - client: 초기화된 Google Cloud Vision 클라이언트.
    - image_url: 처리할 이미지의 URL.

    Returns:
    - 이미지에서 추출된 정보를 포함하는 딕셔너리.
    """
    # 이미지 객체를 생성하고 주어진 URL로 소스를 설정합니다.
    image = vision.Image()
    image.source.image_uri = image_url

    # 이미지에서 추출하려는 기능들을 정의합니다.
    features = [
        {"type_": vision.Feature.Type.TEXT_DETECTION},
        {"type_": vision.Feature.Type.FACE_DETECTION},
        {"type_": vision.Feature.Type.SAFE_SEARCH_DETECTION}
    ]

    # 이미지에 대한 정보를 추출하는 요청을 보냅니다.
    response = client.annotate_image({"image": image, "features": features})

    # 텍스트 데이터를 추출합니다.
    texts = response.text_annotations
    text_data = {"text": "", "area": 0, "area_percentage": 0, "char_count": 0}
    for text in texts[1:]:
        char_count = len(text.description)
        vertices = text.bounding_poly.vertices
        width = vertices[1].x - vertices[0].x
        height = vertices[3].y - vertices[0].y
        area = width * height
        area_percentage = round((area / 57600) * 100, 2)
        char_area = int(area / char_count)
        char_area_percentage = round((char_area / 57600) * 100, 2)

        if char_area_percentage >= 0.35:
            text_data["text"] += text.description + ' '
            text_data["area"] += area
            text_data["area_percentage"] += area_percentage
            text_data["char_count"] += char_count

    # 얼굴 감지
    has_face = 1 if response.face_annotations else 0

    # 유해한 콘텐츠 감지
    violence = response.safe_search_annotation.violence
    racy = response.safe_search_annotation.racy

    return {
        "text": text_data["text"].strip(),
        "char_count": text_data["char_count"],
        "total_area": text_data["area"],
        "total_area_percentage": text_data["area_percentage"],
        "char_area": int(text_data["area"] / text_data["char_count"]) if text_data["char_count"] > 0 else 0,
        "char_area_percentage": round(text_data["area_percentage"] / text_data["char_count"], 2) if text_data["char_count"] > 0 else 0,
        "has_face": has_face,
        "violence": violence,
        "racy": racy
    }

def detect_and_update_csv(csv_filename, debug_interval=50):
    """
    CSV 파일을 읽어 이미지 URL을 처리하고 결과를 CSV 파일에 업데이트합니다.

    Args:
    - csv_filename: 처리할 CSV 파일의 이름.
    - debug_interval: 디버그 메시지를 출력할 간격.
    """
    client = vision.ImageAnnotatorClient()

    # CSV 파일을 읽어 각 행을 리스트로 저장합니다.
    with open(csv_filename, 'r', newline='', encoding='utf-8') as csvfile:
        rows = list(csv.DictReader(csvfile))
        fieldnames = rows[0].keys()

    # 이미지 URL을 키로 사용하여 각 행을 딕셔너리에 저장합니다.
    url_to_row_map = {row["thumbnail_url"]: row for row in rows}

    # 결과를 CSV 파일에 저장하는 함수
    def save_to_csv():
        # "_updated"를 추가하여 새로운 파일 이름을 생성합니다.
        new_csv_filename = csv_filename.replace('.csv', '_updated.csv')
        with open(new_csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
            csv_writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            csv_writer.writeheader()
            csv_writer.writerows(rows)

    # 각 이미지 URL을 처리합니다.
    for i, (image_url, row) in enumerate(url_to_row_map.items(), start=1):
        try:
            result = process_image(client, image_url)
            row.update(result)

            if i % debug_interval == 0:
                print(f"{len(url_to_row_map)}개의 썸네일 중 {i}개가 처리되었습니다")

        except ResourceExhausted:
            print(f"API 요청 제한으로 인해 작업이 중단되었습니다. 처리 중이던 썸네일: {image_url}")
            save_to_csv()
            return
        except Exception as e:
            print(f"처리 중이던 에러 썸네일: {image_url}")
            print(f"에러 메시지: {str(e)}")

    # 모든 이미지 처리가 완료된 후 결과를 CSV 파일에 저장합니다.
    save_to_csv()
    print("처리 완료되었습니다!")

detect_and_update_csv('part_2_230920_1144.csv')
# Out:
# 13432개의 썸네일 중 50개가 처리되었습니다
# 13432개의 썸네일 중 100개가 처리되었습니다
# 13432개의 썸네일 중 150개가 처리되었습니다
# 13432개의 썸네일 중 200개가 처리되었습니다
# 13432개의 썸네일 중 250개가 처리되었습니다
# 13432개의 썸네일 중 300개가 처리되었습니다
# 13432개의 썸네일 중 350개가 처리되었습니다
# 13432개의 썸네일 중 400개가 처리되었습니다
# 13432개의 썸네일 중 450개가 처리되었습니다
# 13432개의 썸네일 중 500개가 처리되었습니다
# 13432개의 썸네일 중 550개가 처리되었습니다
# 13432개의 썸네일 중 600개가 처리되었습니다
# 13432개의 썸네일 중 650개가 처리되었습니다
# 13432개의 썸네일 중 700개가 처리되었습니다
# 13432개의 썸네일 중 750개가 처리되었습니다
# 13432개의 썸네일 중 800개가 처리되었습니다
# 13432개의 썸네일 중 850개가 처리되었습니다
# 13432개의 썸네일 중 900개가 처리되었습니다
# 13432개의 썸네일 중 950개가 처리되었습니다
# 13432개의 썸네일 중 1000개가 처리되었습니다
# 13432개의 썸네일 중 1050개가 처리되었습니다
# 13432개의 썸네일 중 1100개가 처리되었습니다
# 13432개의 썸네일 중 1150개가 처리되었습니다
# 13432개의 썸네일 중 1200개가 처리되었습니다
# 13432개의 썸네일 중 1250개가 처리되었습니다
# 13432개의 썸네일 중 1300개가 처리되었습니다
# 13432개의 썸네일 중 1350개가 처리되었습니다
# 13432개의 썸네일 중 1400개가 처리되었습니다
# 13432개의 썸네일 중 1450개가 처리되었습니다
# 13432개의 썸네일 중 1500개가 처리되었습니다
# 13432개의 썸네일 중 1550개가 처리되었습니다
# 13432개의 썸네일 중 1600개가 처리되었습니다
# 13432개의 썸네일 중 1650개가 처리되었습니다
# 13432개의 썸네일 중 1700개가 처리되었습니다
# 13432개의 썸네일 중 1750개가 처리되었습니다
# 13432개의 썸네일 중 1800개가 처리되었습니다
# 13432개의 썸네일 중 1850개가 처리되었습니다
# 13432개의 썸네일 중 1900개가 처리되었습니다
# 13432개의 썸네일 중 1950개가 처리되었습니다
# 13432개의 썸네일 중 2000개가 처리되었습니다
# 13432개의 썸네일 중 2050개가 처리되었습니다
# 13432개의 썸네일 중 2100개가 처리되었습니다
# 13432개의 썸네일 중 2150개가 처리되었습니다
# 13432개의 썸네일 중 2200개가 처리되었습니다
# 13432개의 썸네일 중 2250개가 처리되었습니다
# 13432개의 썸네일 중 2300개가 처리되었습니다
# 13432개의 썸네일 중 2350개가 처리되었습니다
# 13432개의 썸네일 중 2400개가 처리되었습니다
# 13432개의 썸네일 중 2450개가 처리되었습니다
# 13432개의 썸네일 중 2500개가 처리되었습니다
# 13432개의 썸네일 중 2550개가 처리되었습니다
# 13432개의 썸네일 중 2600개가 처리되었습니다
# 13432개의 썸네일 중 2650개가 처리되었습니다
# 13432개의 썸네일 중 2700개가 처리되었습니다
# 13432개의 썸네일 중 2750개가 처리되었습니다
# 13432개의 썸네일 중 2800개가 처리되었습니다
# 13432개의 썸네일 중 2850개가 처리되었습니다
# 13432개의 썸네일 중 2900개가 처리되었습니다
# 13432개의 썸네일 중 2950개가 처리되었습니다
# 13432개의 썸네일 중 3000개가 처리되었습니다
# 13432개의 썸네일 중 3050개가 처리되었습니다
# 13432개의 썸네일 중 3100개가 처리되었습니다
# 13432개의 썸네일 중 3150개가 처리되었습니다
# 13432개의 썸네일 중 3200개가 처리되었습니다
# 13432개의 썸네일 중 3250개가 처리되었습니다
# 13432개의 썸네일 중 3300개가 처리되었습니다
# 13432개의 썸네일 중 3350개가 처리되었습니다
# 13432개의 썸네일 중 3400개가 처리되었습니다
# 13432개의 썸네일 중 3450개가 처리되었습니다
# 13432개의 썸네일 중 3500개가 처리되었습니다
# 13432개의 썸네일 중 3550개가 처리되었습니다
# 13432개의 썸네일 중 3600개가 처리되었습니다
# 13432개의 썸네일 중 3650개가 처리되었습니다
# 13432개의 썸네일 중 3700개가 처리되었습니다
# 13432개의 썸네일 중 3750개가 처리되었습니다
# 13432개의 썸네일 중 3800개가 처리되었습니다
# 13432개의 썸네일 중 3850개가 처리되었습니다
# 13432개의 썸네일 중 3900개가 처리되었습니다
# 13432개의 썸네일 중 3950개가 처리되었습니다
# 13432개의 썸네일 중 4000개가 처리되었습니다
# 13432개의 썸네일 중 4050개가 처리되었습니다
# 13432개의 썸네일 중 4100개가 처리되었습니다
# 13432개의 썸네일 중 4150개가 처리되었습니다
# 13432개의 썸네일 중 4200개가 처리되었습니다
# 13432개의 썸네일 중 4250개가 처리되었습니다
# 13432개의 썸네일 중 4300개가 처리되었습니다
# 13432개의 썸네일 중 4350개가 처리되었습니다
# 13432개의 썸네일 중 4400개가 처리되었습니다
# 13432개의 썸네일 중 4450개가 처리되었습니다
# 13432개의 썸네일 중 4500개가 처리되었습니다
# 13432개의 썸네일 중 4550개가 처리되었습니다
# 13432개의 썸네일 중 4600개가 처리되었습니다
# 13432개의 썸네일 중 4650개가 처리되었습니다
# 13432개의 썸네일 중 4700개가 처리되었습니다
# 13432개의 썸네일 중 4750개가 처리되었습니다
# 13432개의 썸네일 중 4800개가 처리되었습니다
# 13432개의 썸네일 중 4850개가 처리되었습니다
# 13432개의 썸네일 중 4900개가 처리되었습니다
# 13432개의 썸네일 중 4950개가 처리되었습니다
# 13432개의 썸네일 중 5000개가 처리되었습니다
# 13432개의 썸네일 중 5050개가 처리되었습니다
# 13432개의 썸네일 중 5100개가 처리되었습니다
# 13432개의 썸네일 중 5150개가 처리되었습니다
# 13432개의 썸네일 중 5200개가 처리되었습니다
# 13432개의 썸네일 중 5250개가 처리되었습니다
# 13432개의 썸네일 중 5300개가 처리되었습니다
# 13432개의 썸네일 중 5350개가 처리되었습니다
# 13432개의 썸네일 중 5400개가 처리되었습니다
# 13432개의 썸네일 중 5450개가 처리되었습니다
# 13432개의 썸네일 중 5500개가 처리되었습니다
# 13432개의 썸네일 중 5550개가 처리되었습니다
# 13432개의 썸네일 중 5600개가 처리되었습니다
# 13432개의 썸네일 중 5650개가 처리되었습니다
# 13432개의 썸네일 중 5700개가 처리되었습니다
# 13432개의 썸네일 중 5750개가 처리되었습니다
# 13432개의 썸네일 중 5800개가 처리되었습니다
# 13432개의 썸네일 중 5850개가 처리되었습니다
# 13432개의 썸네일 중 5900개가 처리되었습니다
# 13432개의 썸네일 중 5950개가 처리되었습니다
# 13432개의 썸네일 중 6000개가 처리되었습니다
# 13432개의 썸네일 중 6050개가 처리되었습니다
# 13432개의 썸네일 중 6100개가 처리되었습니다
# 13432개의 썸네일 중 6150개가 처리되었습니다
# 13432개의 썸네일 중 6200개가 처리되었습니다
# 13432개의 썸네일 중 6250개가 처리되었습니다
# 13432개의 썸네일 중 6300개가 처리되었습니다
# 13432개의 썸네일 중 6350개가 처리되었습니다
# 13432개의 썸네일 중 6400개가 처리되었습니다
# 13432개의 썸네일 중 6450개가 처리되었습니다
# 13432개의 썸네일 중 6500개가 처리되었습니다
# 13432개의 썸네일 중 6550개가 처리되었습니다
# 13432개의 썸네일 중 6600개가 처리되었습니다
# 13432개의 썸네일 중 6650개가 처리되었습니다
# 13432개의 썸네일 중 6700개가 처리되었습니다
# 13432개의 썸네일 중 6750개가 처리되었습니다
# 13432개의 썸네일 중 6800개가 처리되었습니다
# 13432개의 썸네일 중 6850개가 처리되었습니다
# 13432개의 썸네일 중 6900개가 처리되었습니다
# 13432개의 썸네일 중 6950개가 처리되었습니다
# 13432개의 썸네일 중 7000개가 처리되었습니다
# 13432개의 썸네일 중 7050개가 처리되었습니다
# 13432개의 썸네일 중 7100개가 처리되었습니다
# 13432개의 썸네일 중 7150개가 처리되었습니다
# 13432개의 썸네일 중 7200개가 처리되었습니다
# 13432개의 썸네일 중 7250개가 처리되었습니다
# 13432개의 썸네일 중 7300개가 처리되었습니다
# 13432개의 썸네일 중 7350개가 처리되었습니다
# 13432개의 썸네일 중 7400개가 처리되었습니다
# 13432개의 썸네일 중 7450개가 처리되었습니다
# 13432개의 썸네일 중 7500개가 처리되었습니다
# 13432개의 썸네일 중 7550개가 처리되었습니다
# 13432개의 썸네일 중 7600개가 처리되었습니다
# 13432개의 썸네일 중 7650개가 처리되었습니다
# 13432개의 썸네일 중 7700개가 처리되었습니다
# 13432개의 썸네일 중 7750개가 처리되었습니다
# 13432개의 썸네일 중 7800개가 처리되었습니다
# 13432개의 썸네일 중 7850개가 처리되었습니다
# 13432개의 썸네일 중 7900개가 처리되었습니다
# 13432개의 썸네일 중 7950개가 처리되었습니다
# 13432개의 썸네일 중 8000개가 처리되었습니다
# 13432개의 썸네일 중 8050개가 처리되었습니다
# 13432개의 썸네일 중 8100개가 처리되었습니다
# 13432개의 썸네일 중 8150개가 처리되었습니다
# 13432개의 썸네일 중 8200개가 처리되었습니다
# 13432개의 썸네일 중 8250개가 처리되었습니다
# 13432개의 썸네일 중 8300개가 처리되었습니다
# 13432개의 썸네일 중 8350개가 처리되었습니다
# 13432개의 썸네일 중 8400개가 처리되었습니다
# 13432개의 썸네일 중 8450개가 처리되었습니다
# 13432개의 썸네일 중 8500개가 처리되었습니다
# 13432개의 썸네일 중 8550개가 처리되었습니다
# 13432개의 썸네일 중 8600개가 처리되었습니다
# 13432개의 썸네일 중 8650개가 처리되었습니다
# 13432개의 썸네일 중 8700개가 처리되었습니다
# 13432개의 썸네일 중 8750개가 처리되었습니다
# 13432개의 썸네일 중 8800개가 처리되었습니다
# 13432개의 썸네일 중 8850개가 처리되었습니다
# 13432개의 썸네일 중 8900개가 처리되었습니다
# 13432개의 썸네일 중 8950개가 처리되었습니다
# 13432개의 썸네일 중 9000개가 처리되었습니다
# 13432개의 썸네일 중 9050개가 처리되었습니다
# 13432개의 썸네일 중 9100개가 처리되었습니다
# 13432개의 썸네일 중 9150개가 처리되었습니다
# 13432개의 썸네일 중 9200개가 처리되었습니다
# 13432개의 썸네일 중 9250개가 처리되었습니다
# 13432개의 썸네일 중 9300개가 처리되었습니다
# 13432개의 썸네일 중 9350개가 처리되었습니다
# 13432개의 썸네일 중 9400개가 처리되었습니다
# 13432개의 썸네일 중 9450개가 처리되었습니다
# 13432개의 썸네일 중 9500개가 처리되었습니다
# 13432개의 썸네일 중 9550개가 처리되었습니다
# 13432개의 썸네일 중 9600개가 처리되었습니다
# 13432개의 썸네일 중 9650개가 처리되었습니다
# 13432개의 썸네일 중 9700개가 처리되었습니다
# 13432개의 썸네일 중 9750개가 처리되었습니다
# 13432개의 썸네일 중 9800개가 처리되었습니다
# 13432개의 썸네일 중 9850개가 처리되었습니다
# 13432개의 썸네일 중 9900개가 처리되었습니다
# 13432개의 썸네일 중 9950개가 처리되었습니다
# 13432개의 썸네일 중 10000개가 처리되었습니다
# 13432개의 썸네일 중 10050개가 처리되었습니다
# 13432개의 썸네일 중 10100개가 처리되었습니다
# 13432개의 썸네일 중 10150개가 처리되었습니다
# 13432개의 썸네일 중 10200개가 처리되었습니다
# 13432개의 썸네일 중 10250개가 처리되었습니다
# 13432개의 썸네일 중 10300개가 처리되었습니다
# 13432개의 썸네일 중 10350개가 처리되었습니다
# 13432개의 썸네일 중 10400개가 처리되었습니다
# 13432개의 썸네일 중 10450개가 처리되었습니다
# 13432개의 썸네일 중 10500개가 처리되었습니다
# 13432개의 썸네일 중 10550개가 처리되었습니다
# 13432개의 썸네일 중 10600개가 처리되었습니다
# 13432개의 썸네일 중 10650개가 처리되었습니다
# 13432개의 썸네일 중 10700개가 처리되었습니다
# 13432개의 썸네일 중 10750개가 처리되었습니다
# 13432개의 썸네일 중 10800개가 처리되었습니다
# 13432개의 썸네일 중 10850개가 처리되었습니다
# 13432개의 썸네일 중 10900개가 처리되었습니다
# 13432개의 썸네일 중 10950개가 처리되었습니다
# 13432개의 썸네일 중 11000개가 처리되었습니다
# 13432개의 썸네일 중 11050개가 처리되었습니다
# 13432개의 썸네일 중 11100개가 처리되었습니다
# 13432개의 썸네일 중 11150개가 처리되었습니다
# 13432개의 썸네일 중 11200개가 처리되었습니다
# 13432개의 썸네일 중 11250개가 처리되었습니다
# 13432개의 썸네일 중 11300개가 처리되었습니다
# 13432개의 썸네일 중 11350개가 처리되었습니다
# 13432개의 썸네일 중 11400개가 처리되었습니다
# 13432개의 썸네일 중 11450개가 처리되었습니다
# 13432개의 썸네일 중 11500개가 처리되었습니다
# 13432개의 썸네일 중 11550개가 처리되었습니다
# 13432개의 썸네일 중 11600개가 처리되었습니다
# 13432개의 썸네일 중 11650개가 처리되었습니다
# 13432개의 썸네일 중 11700개가 처리되었습니다
# 13432개의 썸네일 중 11750개가 처리되었습니다
# 13432개의 썸네일 중 11800개가 처리되었습니다
# 13432개의 썸네일 중 11850개가 처리되었습니다
# 13432개의 썸네일 중 11900개가 처리되었습니다
# 13432개의 썸네일 중 11950개가 처리되었습니다
# 13432개의 썸네일 중 12000개가 처리되었습니다
# 13432개의 썸네일 중 12050개가 처리되었습니다
# 13432개의 썸네일 중 12100개가 처리되었습니다
# 13432개의 썸네일 중 12150개가 처리되었습니다
# 13432개의 썸네일 중 12200개가 처리되었습니다
# 13432개의 썸네일 중 12250개가 처리되었습니다
# 13432개의 썸네일 중 12300개가 처리되었습니다
# 13432개의 썸네일 중 12350개가 처리되었습니다
# 13432개의 썸네일 중 12400개가 처리되었습니다
# 13432개의 썸네일 중 12450개가 처리되었습니다
# 13432개의 썸네일 중 12500개가 처리되었습니다
# 13432개의 썸네일 중 12550개가 처리되었습니다
# 13432개의 썸네일 중 12600개가 처리되었습니다
# 13432개의 썸네일 중 12650개가 처리되었습니다
# 13432개의 썸네일 중 12700개가 처리되었습니다
# 13432개의 썸네일 중 12750개가 처리되었습니다
# 13432개의 썸네일 중 12800개가 처리되었습니다
# 13432개의 썸네일 중 12850개가 처리되었습니다
# 13432개의 썸네일 중 12900개가 처리되었습니다
# 13432개의 썸네일 중 12950개가 처리되었습니다
# 13432개의 썸네일 중 13000개가 처리되었습니다
# 13432개의 썸네일 중 13050개가 처리되었습니다
# 13432개의 썸네일 중 13100개가 처리되었습니다
# 13432개의 썸네일 중 13150개가 처리되었습니다
# 13432개의 썸네일 중 13200개가 처리되었습니다
# 13432개의 썸네일 중 13250개가 처리되었습니다
# 13432개의 썸네일 중 13300개가 처리되었습니다
# 13432개의 썸네일 중 13350개가 처리되었습니다
# 13432개의 썸네일 중 13400개가 처리되었습니다
# 처리 완료되었습니다!
